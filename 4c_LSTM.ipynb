# %%
import numpy as np
import pandas as pd
import pickle
from joblib import dump, load
import matplotlib.pyplot as plt
import gensim
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Activation, Dense, Dropout, Input, Embedding, Flatten, LayerNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.regularizers import L2
from tensorflow.config import list_physical_devices
from bayes_opt import BayesianOptimization

# %%
gpus = list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
# Out:
# Name: /physical_device:GPU:0   Type: GPU

# %% [markdown]
# # Load Data

# %%
df_train = pd.read_csv("X_train_stemm_cleaned.csv")
df_valid = pd.read_csv("X_valid_stemm_cleaned.csv")
df_test = pd.read_csv("X_test_stemm_cleaned.csv")

X_train_clean = df_train['tweet_stemming']
X_valid_clean = df_valid['tweet_stemming']
X_test_clean = df_test['tweet_stemming']

y_train = pd.read_csv("y_train.csv")
y_valid = pd.read_csv("y_valid.csv")
y_test = pd.read_csv("y_test.csv")

# %%
# For SparseCategoricalCrossentropy
with open('y_train_encoded.pkl', 'rb') as file:
    y_train_encoded = pickle.load(file)

with open('y_valid_encoded.pkl', 'rb') as file:
    y_valid_encoded = pickle.load(file)

with open('y_test_encoded.pkl', 'rb') as file:
    y_test_encoded = pickle.load(file)

# %%
# For CategoricalCrossentropy
y_train_encoded = pd.get_dummies(y_train, dtype=float)
y_valid_encoded = pd.get_dummies(y_valid, dtype=float)
y_test_encoded = pd.get_dummies(y_test, dtype=float)

# %% [markdown]
# # LSTM Using TF-IDF

# %%
# Load model TF-IDF
tfidf_vectorizer = load('tfidf_vectorizer.joblib')

# transform set data dari load model tfidf yang telah disimpan
X_train_tfidf = tfidf_vectorizer.transform(X_train_clean)
X_valid_tfidf = tfidf_vectorizer.transform(X_valid_clean)
X_test_tfidf = tfidf_vectorizer.transform(X_test_clean)
# Out:
# C:\Users\andre\anaconda3\envs\tensorflow\lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.0 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\andre\anaconda3\envs\tensorflow\lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.0 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
X_train_tfidf.shape
# Out:
# (1270, 4216)

# %%
# Konversi sparse matrix ke dense array
X_train_dense = X_train_tfidf.toarray()
X_valid_dense = X_valid_tfidf.toarray()
X_test_dense = X_test_tfidf.toarray()

# %%
# LSTM (timesteps = 1)
X_train_lstm = np.expand_dims(X_train_dense, axis=1)
X_valid_lstm = np.expand_dims(X_valid_dense, axis=1)
X_test_lstm = np.expand_dims(X_test_dense, axis=1)

# %% [markdown]
# ## Define Model

# %%
# model LSTM
model = Sequential()
model.add(LSTM(128, input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2]), activation='relu'))
model.add(LayerNormalization()),
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu', kernel_regularizer=L2(0.001)))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu', kernel_regularizer=L2(0.001)))
model.add(Dropout(0.3))
model.add(Dense(3, activation='softmax'))  # Output layer, sesuai dengan jumlah kelas

# compile model
model.compile(loss=CategoricalCrossentropy(),  # cross entropy
              optimizer=Adam(learning_rate=0.0001),    # learning rate 0.0001
              metrics=['accuracy'])

# Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Out:
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# train model
history = model.fit(X_train_lstm, y_train_encoded,
                    validation_data=(X_valid_lstm, y_valid_encoded),
                    epochs=50,  # Sesuaikan dengan jumlah epoch yang diperlukan
                    batch_size=32,
                    callbacks=[early_stopping],
                    verbose=2)
# Out:
# Epoch 1/50
# 40/40 - 1s - loss: 1.2350 - accuracy: 0.3071 - val_loss: 1.2252 - val_accuracy: 0.3480 - 1s/epoch - 33ms/step
# Epoch 2/50
# 40/40 - 0s - loss: 1.2199 - accuracy: 0.3748 - val_loss: 1.2214 - val_accuracy: 0.3663 - 235ms/epoch - 6ms/step
# Epoch 3/50
# 40/40 - 0s - loss: 1.2098 - accuracy: 0.4016 - val_loss: 1.2170 - val_accuracy: 0.3846 - 230ms/epoch - 6ms/step
# Epoch 4/50
# 40/40 - 0s - loss: 1.1971 - accuracy: 0.4535 - val_loss: 1.2116 - val_accuracy: 0.4029 - 231ms/epoch - 6ms/step
# Epoch 5/50
# 40/40 - 0s - loss: 1.1862 - accuracy: 0.4677 - val_loss: 1.2050 - val_accuracy: 0.4286 - 227ms/epoch - 6ms/step
# Epoch 6/50
# 40/40 - 0s - loss: 1.1731 - accuracy: 0.5110 - val_loss: 1.1965 - val_accuracy: 0.4579 - 225ms/epoch - 6ms/step
# Epoch 7/50
# 40/40 - 0s - loss: 1.1468 - accuracy: 0.5528 - val_loss: 1.1868 - val_accuracy: 0.4615 - 227ms/epoch - 6ms/step
# Epoch 8/50
# 40/40 - 0s - loss: 1.1269 - accuracy: 0.5803 - val_loss: 1.1745 - val_accuracy: 0.4762 - 229ms/epoch - 6ms/step
# Epoch 9/50
# 40/40 - 0s - loss: 1.1028 - accuracy: 0.6047 - val_loss: 1.1600 - val_accuracy: 0.4908 - 245ms/epoch - 6ms/step
# Epoch 10/50
# 40/40 - 0s - loss: 1.0733 - accuracy: 0.6535 - val_loss: 1.1408 - val_accuracy: 0.5092 - 248ms/epoch - 6ms/step
# Epoch 11/50
# 40/40 - 0s - loss: 1.0159 - accuracy: 0.6992 - val_loss: 1.1155 - val_accuracy: 0.5238 - 301ms/epoch - 8ms/step
# Epoch 12/50
# 40/40 - 0s - loss: 0.9499 - accuracy: 0.7441 - val_loss: 1.0898 - val_accuracy: 0.5348 - 253ms/epoch - 6ms/step
# Epoch 13/50
# 40/40 - 0s - loss: 0.8983 - accuracy: 0.7567 - val_loss: 1.0636 - val_accuracy: 0.5495 - 253ms/epoch - 6ms/step
# Epoch 14/50
# 40/40 - 0s - loss: 0.8152 - accuracy: 0.8315 - val_loss: 1.0380 - val_accuracy: 0.5714 - 267ms/epoch - 7ms/step
# Epoch 15/50
# 40/40 - 0s - loss: 0.7664 - accuracy: 0.8165 - val_loss: 1.0168 - val_accuracy: 0.5824 - 254ms/epoch - 6ms/step
# Epoch 16/50
# 40/40 - 0s - loss: 0.6617 - accuracy: 0.8709 - val_loss: 1.0149 - val_accuracy: 0.5934 - 249ms/epoch - 6ms/step
# Epoch 17/50
# 40/40 - 0s - loss: 0.5948 - accuracy: 0.8945 - val_loss: 1.0132 - val_accuracy: 0.5897 - 249ms/epoch - 6ms/step
# Epoch 18/50
# 40/40 - 0s - loss: 0.5251 - accuracy: 0.9008 - val_loss: 1.0198 - val_accuracy: 0.5861 - 252ms/epoch - 6ms/step
# Epoch 19/50
# 40/40 - 0s - loss: 0.4596 - accuracy: 0.9244 - val_loss: 1.0437 - val_accuracy: 0.6007 - 258ms/epoch - 6ms/step
# Epoch 20/50
# 40/40 - 0s - loss: 0.4297 - accuracy: 0.9268 - val_loss: 1.0667 - val_accuracy: 0.6044 - 254ms/epoch - 6ms/step
# Epoch 21/50
# 40/40 - 0s - loss: 0.3705 - accuracy: 0.9449 - val_loss: 1.0931 - val_accuracy: 0.5971 - 268ms/epoch - 7ms/step
# Epoch 22/50
# 40/40 - 0s - loss: 0.3498 - accuracy: 0.9402 - val_loss: 1.1233 - val_accuracy: 0.6044 - 275ms/epoch - 7ms/step
# Epoch 23/50
# 40/40 - 0s - loss: 0.3149 - accuracy: 0.9575 - val_loss: 1.1532 - val_accuracy: 0.5934 - 266ms/epoch - 7ms/step
# Epoch 24/50
# 40/40 - 0s - loss: 0.2883 - accuracy: 0.9646 - val_loss: 1.1906 - val_accuracy: 0.5788 - 277ms/epoch - 7ms/step
# Epoch 25/50
# 40/40 - 0s - loss: 0.2913 - accuracy: 0.9638 - val_loss: 1.2166 - val_accuracy: 0.5897 - 267ms/epoch - 7ms/step
# Epoch 26/50
# 40/40 - 0s - loss: 0.2548 - accuracy: 0.9717 - val_loss: 1.2512 - val_accuracy: 0.5971 - 260ms/epoch - 6ms/step
# Epoch 27/50
# 40/40 - 0s - loss: 0.2361 - accuracy: 0.9764 - val_loss: 1.2853 - val_accuracy: 0.5934 - 263ms/epoch - 7ms/step

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['accuracy', 'val_accuracy']].plot(title="Accuracy")
# Out:
# <Axes: title={'center': 'Accuracy'}>

# %%
# evaluate model
y_pred = model.predict(X_test_lstm)
y_pred_classes = np.argmax(y_pred, axis=1)

# Classification Report
label_ = ["negatif", "netral", "positif"]
print(classification_report(y_test_encoded.values.argmax(axis=1), y_pred_classes, target_names=label_))
# Out:
# 9/9 [==============================] - 0s 4ms/step
#               precision    recall  f1-score   support
#
#      negatif       0.61      0.65      0.63        89
#       netral       0.65      0.58      0.62        91
#      positif       0.55      0.58      0.56        92
#
#     accuracy                           0.60       272
#    macro avg       0.61      0.60      0.60       272
# weighted avg       0.61      0.60      0.60       272

# %%
ConfusionMatrixDisplay.from_predictions(y_test_encoded.values.argmax(axis=1), y_pred_classes, display_labels=label_)
plt.show()

# %% [markdown]
# ## Save Model

# %%
# save model
model.save_weights(
    "lstm_tfidf"
)

# %%
# load model
model.load_weights('lstm_tfidf')

# %%
model.evaluate(X_test_lstm, y_test_encoded, verbose=0)
# Out:
# [0.9980061650276184, 0.6029411554336548]

# %% [markdown]
# # LSTM Using skipgram

# %%
# load model
word2vec_model = gensim.models.word2vec.Word2Vec.load("w2v_skipgram.model")

# %%
max_len = 50
# tok = Tokenizer(num_words=max_words)
tok = Tokenizer()
tok.fit_on_texts(X_train_clean)
sequences_train = tok.texts_to_sequences(X_train_clean)
sequences_matrix_train = pad_sequences(sequences_train,maxlen=max_len)

sequences_valid = tok.texts_to_sequences(X_valid_clean)
sequences_matrix_valid = pad_sequences(sequences_valid,maxlen=max_len)

sequences_test = tok.texts_to_sequences(X_test_clean)
sequences_matrix_test = pad_sequences(sequences_test,maxlen=max_len)

vocab_size = len(tok.word_index) + 1
print("Total words", vocab_size)
# Out:
# Total words 4231

# %%
# WORD2VEC
W2V_SIZE = 75
embedding_matrix = np.zeros((vocab_size, W2V_SIZE))
for word, i in tok.word_index.items():
    if word in word2vec_model.wv:
        embedding_matrix[i] = word2vec_model.wv[word]
    else:
        embedding_matrix[i] = np.zeros(W2V_SIZE)
print(embedding_matrix.shape)
# Out:
# (4231, 75)

# %% [markdown]
# ## Define Model

# %%
# model LSTM
model = Sequential()
model.add(Embedding(input_dim=vocab_size,
                    output_dim=W2V_SIZE,
                    weights=[embedding_matrix],
                    input_length=max_len,
                    trainable=False))  # Set to False to freeze the embeddings
model.add(LSTM(128, input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2]), activation='relu'))
model.add(LayerNormalization()),
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu', kernel_regularizer=L2(0.001)))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu', kernel_regularizer=L2(0.001)))
model.add(Dropout(0.3))
model.add(Dense(3, activation='softmax'))  # Output layer, sesuai dengan jumlah kelas

# compile model
model.compile(loss=CategoricalCrossentropy(),  # cross entropy
              optimizer=Adam(learning_rate=0.0001),    # learning rate 0.0001
              metrics=['accuracy'])

# Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Out:
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# train model
history = model.fit(sequences_matrix_train, y_train_encoded,
                    validation_data=(sequences_matrix_valid, y_valid_encoded),
                    epochs=50,  # Sesuaikan dengan jumlah epoch yang diperlukan
                    batch_size=32,
                    callbacks=[early_stopping],
                    verbose=2)
# Out:
# Epoch 1/50
# 40/40 - 4s - loss: 1.5443 - accuracy: 0.3339 - val_loss: 1.2009 - val_accuracy: 0.3626 - 4s/epoch - 96ms/step
# Epoch 2/50
# 40/40 - 3s - loss: 1.3564 - accuracy: 0.3449 - val_loss: 1.1731 - val_accuracy: 0.4615 - 3s/epoch - 74ms/step
# Epoch 3/50
# 40/40 - 3s - loss: 1.2738 - accuracy: 0.3780 - val_loss: 1.1705 - val_accuracy: 0.4652 - 3s/epoch - 74ms/step
# Epoch 4/50
# 40/40 - 3s - loss: 1.2319 - accuracy: 0.4055 - val_loss: 1.1662 - val_accuracy: 0.4908 - 3s/epoch - 77ms/step
# Epoch 5/50
# 40/40 - 3s - loss: 1.2184 - accuracy: 0.4071 - val_loss: 1.1580 - val_accuracy: 0.4799 - 3s/epoch - 74ms/step
# Epoch 6/50
# 40/40 - 3s - loss: 1.2303 - accuracy: 0.3906 - val_loss: 1.1548 - val_accuracy: 0.4799 - 3s/epoch - 73ms/step
# Epoch 7/50
# 40/40 - 3s - loss: 1.1942 - accuracy: 0.4173 - val_loss: 1.1508 - val_accuracy: 0.4945 - 3s/epoch - 74ms/step
# Epoch 8/50
# 40/40 - 3s - loss: 1.2007 - accuracy: 0.4299 - val_loss: 1.1495 - val_accuracy: 0.4908 - 3s/epoch - 74ms/step
# Epoch 9/50
# 40/40 - 3s - loss: 1.2084 - accuracy: 0.4008 - val_loss: 1.1472 - val_accuracy: 0.5128 - 3s/epoch - 76ms/step
# Epoch 10/50
# 40/40 - 3s - loss: 1.1775 - accuracy: 0.4480 - val_loss: 1.1420 - val_accuracy: 0.5311 - 3s/epoch - 74ms/step
# Epoch 11/50
# 40/40 - 3s - loss: 1.1817 - accuracy: 0.4370 - val_loss: 1.1343 - val_accuracy: 0.5458 - 3s/epoch - 74ms/step
# Epoch 12/50
# 40/40 - 3s - loss: 1.1605 - accuracy: 0.4654 - val_loss: 1.1291 - val_accuracy: 0.5495 - 3s/epoch - 73ms/step
# Epoch 13/50
# 40/40 - 3s - loss: 1.1569 - accuracy: 0.4646 - val_loss: 1.1234 - val_accuracy: 0.5201 - 3s/epoch - 74ms/step
# Epoch 14/50
# 40/40 - 3s - loss: 1.1465 - accuracy: 0.4811 - val_loss: 1.1173 - val_accuracy: 0.5421 - 3s/epoch - 78ms/step
# Epoch 15/50
# 40/40 - 3s - loss: 1.1452 - accuracy: 0.4819 - val_loss: 1.1083 - val_accuracy: 0.5531 - 3s/epoch - 75ms/step
# Epoch 16/50
# 40/40 - 3s - loss: 1.1300 - accuracy: 0.4843 - val_loss: 1.0973 - val_accuracy: 0.5641 - 3s/epoch - 73ms/step
# Epoch 17/50
# 40/40 - 3s - loss: 1.1333 - accuracy: 0.5000 - val_loss: 1.0924 - val_accuracy: 0.5641 - 3s/epoch - 74ms/step
# Epoch 18/50
# 40/40 - 3s - loss: 1.1088 - accuracy: 0.5165 - val_loss: 1.0858 - val_accuracy: 0.5934 - 3s/epoch - 74ms/step
# Epoch 19/50
# 40/40 - 3s - loss: 1.1123 - accuracy: 0.5173 - val_loss: 1.0815 - val_accuracy: 0.5897 - 3s/epoch - 73ms/step
# Epoch 20/50
# 40/40 - 3s - loss: 1.1174 - accuracy: 0.5220 - val_loss: 1.0717 - val_accuracy: 0.5788 - 3s/epoch - 76ms/step
# Epoch 21/50
# 40/40 - 3s - loss: 1.1108 - accuracy: 0.5236 - val_loss: 1.0725 - val_accuracy: 0.5788 - 3s/epoch - 73ms/step
# Epoch 22/50
# 40/40 - 3s - loss: 1.1129 - accuracy: 0.5189 - val_loss: 1.0667 - val_accuracy: 0.5788 - 3s/epoch - 73ms/step
# Epoch 23/50
# 40/40 - 3s - loss: 1.0936 - accuracy: 0.5299 - val_loss: 1.0627 - val_accuracy: 0.5714 - 3s/epoch - 74ms/step
# Epoch 24/50
# 40/40 - 3s - loss: 1.0911 - accuracy: 0.5425 - val_loss: 1.0583 - val_accuracy: 0.5568 - 3s/epoch - 73ms/step
# Epoch 25/50
# 40/40 - 3s - loss: 1.0987 - accuracy: 0.5165 - val_loss: 1.0533 - val_accuracy: 0.5897 - 3s/epoch - 77ms/step
# Epoch 26/50
# 40/40 - 3s - loss: 1.0735 - accuracy: 0.5370 - val_loss: 1.0500 - val_accuracy: 0.5861 - 3s/epoch - 73ms/step
# Epoch 27/50
# 40/40 - 3s - loss: 1.0907 - accuracy: 0.5291 - val_loss: 1.0436 - val_accuracy: 0.6007 - 3s/epoch - 74ms/step
# Epoch 28/50
# 40/40 - 3s - loss: 1.0927 - accuracy: 0.5244 - val_loss: 1.0445 - val_accuracy: 0.5934 - 3s/epoch - 74ms/step
# Epoch 29/50
# 40/40 - 3s - loss: 1.0337 - accuracy: 0.5819 - val_loss: 1.0321 - val_accuracy: 0.6081 - 3s/epoch - 73ms/step
# Epoch 30/50
# 40/40 - 3s - loss: 1.0441 - accuracy: 0.5528 - val_loss: 1.0348 - val_accuracy: 0.5971 - 3s/epoch - 76ms/step
# Epoch 31/50
# 40/40 - 3s - loss: 1.0604 - accuracy: 0.5638 - val_loss: 1.0285 - val_accuracy: 0.5861 - 3s/epoch - 75ms/step
# Epoch 32/50
# 40/40 - 3s - loss: 1.0421 - accuracy: 0.5764 - val_loss: 1.0240 - val_accuracy: 0.5861 - 3s/epoch - 73ms/step
# Epoch 33/50
# 40/40 - 3s - loss: 1.0449 - accuracy: 0.5622 - val_loss: 1.0254 - val_accuracy: 0.5934 - 3s/epoch - 74ms/step
# Epoch 34/50
# 40/40 - 3s - loss: 1.0547 - accuracy: 0.5772 - val_loss: 1.0223 - val_accuracy: 0.6044 - 3s/epoch - 73ms/step
# Epoch 35/50
# 40/40 - 3s - loss: 1.0225 - accuracy: 0.5701 - val_loss: 1.0195 - val_accuracy: 0.5971 - 3s/epoch - 73ms/step
# Epoch 36/50
# 40/40 - 3s - loss: 0.9965 - accuracy: 0.5906 - val_loss: 1.0180 - val_accuracy: 0.5897 - 3s/epoch - 75ms/step
# Epoch 37/50
# 40/40 - 3s - loss: 1.0181 - accuracy: 0.5976 - val_loss: 1.0146 - val_accuracy: 0.6117 - 3s/epoch - 73ms/step
# Epoch 38/50
# 40/40 - 3s - loss: 1.0099 - accuracy: 0.5890 - val_loss: 1.0119 - val_accuracy: 0.6007 - 3s/epoch - 74ms/step
# Epoch 39/50
# 40/40 - 3s - loss: 1.0115 - accuracy: 0.5835 - val_loss: 1.0118 - val_accuracy: 0.6044 - 3s/epoch - 74ms/step
# Epoch 40/50
# 40/40 - 3s - loss: 1.0007 - accuracy: 0.6094 - val_loss: 1.0120 - val_accuracy: 0.6081 - 3s/epoch - 74ms/step
# Epoch 41/50
# 40/40 - 3s - loss: 0.9953 - accuracy: 0.6087 - val_loss: 1.0082 - val_accuracy: 0.5934 - 3s/epoch - 76ms/step
# Epoch 42/50
# 40/40 - 3s - loss: 0.9921 - accuracy: 0.6071 - val_loss: 1.0126 - val_accuracy: 0.6007 - 3s/epoch - 73ms/step
# Epoch 43/50
# 40/40 - 3s - loss: 0.9856 - accuracy: 0.6102 - val_loss: 1.0098 - val_accuracy: 0.5897 - 3s/epoch - 74ms/step
# Epoch 44/50
# 40/40 - 3s - loss: 0.9791 - accuracy: 0.6055 - val_loss: 1.0088 - val_accuracy: 0.6081 - 3s/epoch - 74ms/step
# Epoch 45/50
# 40/40 - 3s - loss: 0.9737 - accuracy: 0.6047 - val_loss: 1.0054 - val_accuracy: 0.6044 - 3s/epoch - 74ms/step
# Epoch 46/50
# 40/40 - 3s - loss: 0.9521 - accuracy: 0.6268 - val_loss: 1.0027 - val_accuracy: 0.6154 - 3s/epoch - 74ms/step
# Epoch 47/50
# 40/40 - 3s - loss: 0.9834 - accuracy: 0.6126 - val_loss: 1.0052 - val_accuracy: 0.5861 - 3s/epoch - 76ms/step
# Epoch 48/50
# 40/40 - 3s - loss: 0.9686 - accuracy: 0.6126 - val_loss: 1.0077 - val_accuracy: 0.6044 - 3s/epoch - 73ms/step
# Epoch 49/50
# 40/40 - 3s - loss: 0.9643 - accuracy: 0.6142 - val_loss: 1.0103 - val_accuracy: 0.6044 - 3s/epoch - 73ms/step
# Epoch 50/50
# 40/40 - 3s - loss: 0.9571 - accuracy: 0.6402 - val_loss: 1.0053 - val_accuracy: 0.6117 - 3s/epoch - 73ms/step

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['accuracy', 'val_accuracy']].plot(title="Accuracy")
# Out:
# <Axes: title={'center': 'Accuracy'}>

# %%
# evaluate model
y_pred = model.predict(sequences_matrix_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Classification Report
label_ = ["negatif", "netral", "positif"]
print(classification_report(y_test_encoded.values.argmax(axis=1), y_pred_classes, target_names=label_))
# Out:
# 9/9 [==============================] - 0s 19ms/step
#               precision    recall  f1-score   support
#
#      negatif       0.55      0.73      0.63        89
#       netral       0.68      0.49      0.57        91
#      positif       0.56      0.53      0.54        92
#
#     accuracy                           0.58       272
#    macro avg       0.60      0.59      0.58       272
# weighted avg       0.60      0.58      0.58       272

# %%
ConfusionMatrixDisplay.from_predictions(y_test_encoded.values.argmax(axis=1), y_pred_classes, display_labels=label_)
plt.show()

# %% [markdown]
# ## Save Model

# %%
# save model
model.save_weights(
    "lstm_word2vec"
)

# %%
# load model
model.load_weights('lstm_word2vec')

# %%
model.evaluate(sequences_matrix_test, y_test_encoded, verbose=0)
# Out:
# [0.9939942359924316, 0.5845588445663452]
